# %% [markdown]
# # 🏈 Super Bowl Analytics with Polars
#
# ## Welcome to the DataCamp Code-Along!
#
# In this session, we'll answer the ultimate question:
#
# > **Can we mathematically predict the Super Bowl winner?**
#
# ---
#
# ## 📓 Notebooks
#
# Please follow along in order:
#
# | # | Notebook | Description |
# |---|----------|-------------|
# | 1 | [live_01_setup_and_ingestion.ipynb](live_01_setup_and_ingestion.ipynb) | Environment setup, data loading, Polars vs Pandas speed test |
# | 2 | [live_02_era_of_the_quarterback.ipynb](live_02_era_of_the_quarterback.ipynb) | Analyze passing efficiency trends, prove the NFL is a passing league |
# | 3 | [live_03_madden_oracle.ipynb](live_03_madden_oracle.ipynb) | String cleaning, Madden ratings as talent proxy |
# | 4 | [live_04_prediction_machine.ipynb](live_04_prediction_machine.ipynb) | Build ML model, predict this year's Super Bowl winner! 🏆 |
#
# ---
#
# ## 🎯 Key Learning Points
#
# 1. **Polars Efficiency** — Why it's faster than Pandas (Lazy evaluation, Arrow memory)
# 2. **Expression API** — Writing clean, readable code with `pl.col()`
# 3. **Data Wrangling** — Filtering, grouping, and joining complex datasets
# 4. **NFL Analytics** — Understanding EPA (Expected Points Added) and modern metrics
#
# ---
#
# **Start with → [live_01_setup_and_ingestion.ipynb](live_01_setup_and_ingestion.ipynb)**
